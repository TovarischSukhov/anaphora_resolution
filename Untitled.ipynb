# %%
import pandas as pd

# %%
with open('../rucoref_29/Tokens.txt') as f:
    tokens = f.read()
with open('../rucoref_29/Groups.txt') as f:
    coreference = f.read()
    
#prons = 'он она оно они его её их мой'.split()

# %%
tokens = pd.read_csv('../rucoref_29/Tokens.txt', sep='\t')
tokens = tokens.rename(index=str, columns={"shift": "shift_o", "length": "length_o"})
tokens.head()
# Out:
#    doc_id  shift_o  length_o     token     lemma     gram
# 0       1        0         2        Во        во     Sp-a
# 1       1        3         5     время     время   Ncnsan
# 2       1        9         5     своих      свой  P---pga
# 3       1       15         8  прогулок  прогулка   Ncfpgn
# 4       1       24         1         в         в     Sp-l

# %%
coreference = pd.read_csv('../rucoref_29/Groups.txt', sep='\t')

coreference.head()
# Out:
#    doc_id  variant  group_id  chain_id    link  shift  length        content  \
# 0       1        1    407840      1070       0      9       5          своих
# 1       1        1    407839      1070  407840     47       1              я
# 2       1        1    407842      1069       0     69      13  одинокую дачу
# 3       1        1    407841      1069  407842    118       9      этой даче
# 4       1        1    407843      1069  407841    166       3            она
#
#   tk_shifts                   attributes  head hd_shifts
# 0         9  ref:def|str:refl|type:coref   NaN       NaN
# 1        47  ref:def|str:pron|type:coref   NaN       NaN
# 2     69,78  ref:def|str:noun|type:coref  дачу        78
# 3   118,123  ref:def|str:noun|type:coref  даче       123
# 4       166  ref:def|str:pron|type:coref   NaN       NaN

# %%
cor_list = coreference.values.tolist()
tokens_with_coref = tokens.copy()
cols = coreference.columns.values.tolist()
cols.pop(0)

tokens_with_coref = tokens_with_coref.reindex(columns = tokens.columns.values.tolist() + cols + ['anaph'])

for i in range(len(tokens)):
    if tokens['shift_o'][i] == cor_list[0][5]:
        for col_n in range(len(cols)):
            tokens_with_coref.iloc[i, col_n+6] = cor_list[0][col_n+1]
        #print('added:')
        if len(str(cor_list[0][9]).split('|')) > 1:
            if cor_list[0][9].split('|')[2].split(':')[1] == 'anaph':
                tokens_with_coref.iloc[i, 17] = 1
        if cor_list[0][5] != cor_list[1][5]:
            cor_list.pop(0)
        else:
            row = tokens.iloc[i].values.tolist() + cor_list[1][1:]
            tokens_with_coref.append(row)
            cor_list.pop(0)
            cor_list.pop(0)
    print(tokens['shift_o'][i] == cor_list[0][5], cor_list[0][5], cor_list[0][7])
# Out:
# False 9 своих
# False 9 своих
# False 47 я
# False 47 я
# False 47 я
# False 47 я
# False 47 я
# False 69 одинокую дачу
# False 69 одинокую дачу
# False 69 одинокую дачу
# False 69 одинокую дачу
# False 118 этой даче
# False 118 этой даче
# False 118 этой даче
# False 118 этой даче
# False 118 этой даче
# False 118 этой даче
# False 118 этой даче
# False 118 этой даче
# False 118 этой даче
# False 118 этой даче
# False 166 она
# False 166 она
# False 166 она
# False 166 она
# False 166 она
# False 166 она
# False 166 она
# False 166 она
# False 166 она
# False 184 высоким забором
# False 184 высоким забором
# False 184 высоким забором
# False 203 единственной низкой калиткой
# False 203 единственной низкой калиткой
# False 203 единственной низкой калиткой
# False 203 единственной низкой калиткой
# False 233 которая
# False 233 которая
# False 233 которая
# False 233 которая
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 316 забором
# False 332 дачи
# False 332 дачи
# False 332 дачи
# False 337 голые уступы желтоватых скал
# False 337 голые уступы желтоватых скал
# False 371 ними
# False 371 ними
# False 371 ними
# False 371 ними
# False 371 ними
# False 371 ними
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 567 я
# False 583 дачи
# False 583 дачи
# False 583 дачи
# False 583 дачи
# False 589 Я
# False 589 Я
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 658 мое
# False 683 я
# False 683 я
# False 683 я
# False 683 я
# False 683 я
# False 683 я
# False 718 двор таинственного жилища
# False 718 двор таинственного жилища
# False 718 двор таинственного жилища
# False 718 двор таинственного жилища
# False 718 двор таинственного жилища
# False 718 двор таинственного жилища
# False 718 двор таинственного жилища
# False 723 таинственного жилища
# False 782 дача
# False 782 дача
# False 782 дача
# False 782 дача
# False 782 дача
# False 782 дача
# False 782 дача
# False 782 дача
# False 782 дача
# False 824 я
# False 824 я
# False 824 я
# False 824 я
# False 824 я
# False 824 я
# False 824 я
# False 824 я
# False 824 я
# False 838 я
# False 838 я
# False 838 я
# False 838 я
# False 873 двора
# False 873 двора
# False 873 двора
# False 873 двора
# False 873 двора
# False 873 двора
# False 880 Он
# False 880 Он
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 981 мне
# False 1010 двору
# False 1010 двору
# False 1010 двору
# False 1010 двору
# False 1010 двору
# False 1010 двору
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1088 меня
# False 1112 люди
# False 1112 люди
# False 1112 люди
# False 1112 люди
# False 1112 люди
# False 1131 они
# False 1131 они
# False 1131 они
# False 1131 они
# False 1131 они
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1233 Я
# False 1263 своих
# False 1263 своих
# False 1263 своих
# False 1263 своих
# False 1263 своих
# False 1291 мне
# False 1291 мне
# False 1291 мне
# False 1291 мне
# False 1291 мне
# False 1291 мне
# False 1291 мне
# False 1317 мое
# False 1317 мое
# False 1317 мое
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1381 дачи
# False 1412 мне
# False 1412 мне
# False 1412 мне
# False 1412 мне
# False 1412 мне
# False 1412 мне
# False 1443 профессор Вагнер
# False 1443 профессор Вагнер
# False 1443 профессор Вагнер
# False 1443 профессор Вагнер
# False 1443 профессор Вагнер
# False 1443 профессор Вагнер
# False 1443 профессор Вагнер
# False 1443 профессор Вагнер
# False 1443 профессор Вагнер
# False 1461 Профессор Вагнер
# False 1461 Профессор Вагнер
# False 1461 Профессор Вагнер
# False 1529 мое
# False 1529 мое
# False 1529 мое
# False 1529 мое
# False 1529 мое
# False 1529 мое
# False 1529 мое
# False 1529 мое
# False 1529 мое
# False 1529 мое
# False 1544 даче
# False 1544 даче
# False 1544 даче
# False 1550 Мне
# False 1550 Мне
# False 1595 необычайного человека
# False 1595 необычайного человека
# False 1595 необычайного человека
# False 1595 необычайного человека
# False 1595 необычайного человека
# False 1595 необычайного человека
# False 1595 необычайного человека
# False 1595 необычайного человека
# False 1595 необычайного человека
# False 1643 своими
# False 1643 своими
# False 1643 своими
# False 1643 своими
# False 1643 своими
# False 1643 своими
# False 1675 Я
# False 1675 Я
# False 1675 Я
# False 1675 Я
# False 1675 Я
# False 1675 Я
# False 1675 Я
# False 1675 Я
# False 1704 дачей
# False 1704 дачей
# False 1704 дачей
# False 1704 дачей
# False 1704 дачей
# False 1711 Я
# False 1711 Я
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1769 свои
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1845 можжевеловым кустом
# False 1878 дачи
# False 1878 дачи
# False 1878 дачи
# False 1878 дачи
# False 1878 дачи
# False 1898 человек
# False 1898 человек
# False 1898 человек
# False 1898 человек
# False 1898 человек
# False 1928 одну цель
# False 1928 одну цель
# False 1928 одну цель
# False 1958 он
# False 1958 он
# False 1958 он
# False 1958 он
# False 1958 он
# False 1958 он
# False 1958 он
# False 1971 ее
# False 1971 ее
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2021 я
# False 2042 заветная дверь в высоком заборе
# False 2042 заветная дверь в высоком заборе
# False 2042 заветная дверь в высоком заборе
# False 2042 заветная дверь в высоком заборе
# False 2042 заветная дверь в высоком заборе
# False 2059 высоком заборе
# False 2059 высоком заборе
# False 2059 высоком заборе
# False 2085 Я
# False 2085 Я
# False 2085 Я
# False 2085 Я
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2162 Дверь
# False 2179 Высокий человек , с румяным лицом , русой бородой и нависшими усами
# False 2179 Высокий человек , с румяным лицом , русой бородой и нависшими усами
# False 2179 Высокий человек , с румяным лицом , русой бородой и нависшими усами
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2297 он
# False 2301 профессор Вагнер
# False 2301 профессор Вагнер
# False 2354 он
# False 2354 он
# False 2354 он
# False 2354 он
# False 2354 он
# False 2354 он
# False 2354 он
# False 2354 он
# False 2354 он
# False 2354 он
# False 2399 небольшой горной площадки
# False 2399 небольшой горной площадки
# False 2399 небольшой горной площадки
# False 2399 небольшой горной площадки
# False 2399 небольшой горной площадки
# False 2399 небольшой горной площадки
# False 2399 небольшой горной площадки
# False 2399 небольшой горной площадки
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2485 меня
# False 2507 площадке
# False 2507 площадке
# False 2507 площадке
# False 2507 площадке
# False 2532 камни различной величины
# False 2532 камни различной величины
# False 2532 камни различной величины
# False 2558 Вагнер
# False 2558 Вагнер
# False 2558 Вагнер
# False 2558 Вагнер
# False 2576 ним
# False 2576 ним
# False 2576 ним
# False 2604 их
# False 2604 их
# False 2604 их
# False 2604 их
# False 2604 их
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2676 камни
# False 2690 они
# False 2690 они
# False 2690 они
# False 2690 они
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2777 их
# False 2823 я
# False 2823 я
# False 2823 я
# False 2823 я
# False 2823 я
# False 2823 я
# False 2823 я
# False 2823 я
# False 2823 я
# False 2823 я
# False 2823 я
# False 2834 я
# False 2834 я
# False 2834 я
# False 2834 я
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2926 профессор Вагнер
# False 2953 огромному обломку скалы
# False 2953 огромному обломку скалы
# False 2953 огромному обломку скалы
# False 2953 огромному обломку скалы
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3056 обломок
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3132 он
# False 3156 этим обломком скалы
# False 3156 этим обломком скалы
# False 3156 этим обломком скалы
# False 3156 этим обломком скалы
# False 3177 Я
# False 3177 Я
# False 3177 Я
# False 3177 Я
# False 3206 Вагнер
# False 3206 Вагнер
# False 3206 Вагнер
# False 3206 Вагнер
# False 3206 Вагнер
# False 3206 Вагнер
# False 3206 Вагнер
# False 3206 Вагнер
# False 3265 он
# False 3265 он
# False 3265 он
# False 3265 он
# False 3265 он
# False 3265 он
# False 3265 он
# False 3265 он
# False 3320 Я
# False 3320 Я
# False 3320 Я
# False 3320 Я
# False 3320 Я
# False 3320 Я
# False 3320 Я
# False 3320 Я
# False 3320 Я
# False 3320 Я
# False 3340 свою
# False 3340 свою
# False 3340 свою
# False 3340 свою
# False 3368 Вагнера
# False 3368 Вагнера
# False 3368 Вагнера
# False 3368 Вагнера
# False 3368 Вагнера
# False 3368 Вагнера
# False 3395 меня
# False 3395 меня
# False 3395 меня
# False 3395 меня
# False 3401 Вагнер
# False 3401 Вагнер
# False 3415 глыбу
# False 3415 глыбу
# False 3453 она
# False 3453 она
# False 3453 она
# False 3453 она
# False 3453 она
# False 3453 она
# False 3453 она
# False 3453 она
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3529 я
# False 3544 эта глыба
# False 3544 эта глыба
# False 3544 эта глыба
# False 3544 эта глыба
# False 3567 обломок
# False 3567 обломок
# False 3567 обломок
# False 3567 обломок
# False 3567 обломок
# False 3567 обломок
# False 3608 Я
# False 3608 Я
# False 3608 Я
# False 3608 Я
# False 3608 Я
# False 3608 Я
# False 3645 глыба
# False 3645 глыба
# False 3645 глыба
# False 3645 глыба
# False 3645 глыба
# False 3645 глыба
# False 3645 глыба
# False 3677 она
# False 3677 она
# False 3677 она
# False 3677 она
# False 3677 она
# False 3677 она
# False 3677 она
# False 3728 Вагнер
# False 3728 Вагнер
# False 3728 Вагнер
# False 3728 Вагнер
# False 3728 Вагнер
# False 3728 Вагнер
# False 3728 Вагнер
# False 3728 Вагнер
# False 3728 Вагнер
# False 3745 руку
# False 3745 руку
# False 3768 глыбу
# False 3768 глыбу
# False 3768 глыбу
# False 3768 глыбу
# False 3768 глыбу
# False 3782 рука
# False 3782 рука
# False 3782 рука
# False 3787 его
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3847 Вагнер
# False 3876 себя
# False 3876 себя
# False 3876 себя
# False 3876 себя
# False 3876 себя
# False 3881 глыбу
# False 3888 Она
# False 3888 Она
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4073 Вагнер
# False 4137 он
# False 4137 он
# False 4137 он
# False 4137 он
# False 4137 он
# False 4137 он
# False 4137 он
# False 4137 он
# False 4137 он
# False 4137 он
# False 4137 он
# False 4155 площадки
# False 4155 площадки
# False 4155 площадки
# False 4166 мою
# False 4166 мою
# False 4179 Он
# False 4179 Он
# False 4179 Он
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4224 ним
# False 4264 глыбой
# False 4264 глыбой
# False 4264 глыбой
# False 4264 глыбой
# False 4264 глыбой
# False 4264 глыбой
# False 4264 глыбой
# False 4264 глыбой
# False 4264 глыбой
# False 4283 он
# False 4283 он
# False 4283 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4331 он
# False 4340 Вагнер
# False 4340 Вагнер
# False 4340 Вагнер
# False 4380 Он
# False 4380 Он
# False 4380 Он
# False 4380 Он
# False 4380 Он
# False 4380 Он
# False 4380 Он
# False 4380 Он
# False 4402 меня
# False 4402 меня
# False 4402 меня
# False 4402 меня
# False 4426 можжевелового куста
# False 4426 можжевелового куста
# False 4426 можжевелового куста
# False 4426 можжевелового куста
# False 4426 можжевелового куста
# False 4485 колено
# False 4485 колено
# False 4485 колено
# False 4485 колено
# False 4485 колено
# False 4485 колено
# False 4485 колено
# False 4485 колено
# False 4485 колено
# False 4502 ушибленное место
# False 4502 ушибленное место
# False 4502 ушибленное место
# False 4520 он
# False 4520 он
# False 4520 он
# False 4590 я
# False 4590 я
# False 4590 я
# False 4590 я
# False 4590 я
# False 4590 я
# False 4590 я
# False 4590 я
# False 4590 я
# False 4590 я
# False 4590 я
# False 4609 свое
# False 4609 свое
# False 4609 свое
# False 4635 ему
# False 4635 ему
# False 4635 ему
# False 4635 ему
# False 4650 Вы
# False 4650 Вы
# False 4650 Вы
# False 4684 вам
# False 4684 вам
# False 4684 вам
# False 4684 вам
# False 4684 вам
# False 4684 вам
# False 4684 вам
# False 4698 я
# False 4698 я
# False 4698 я
# False 4698 я
# False 4711 куста
# False 4711 куста
# False 4711 куста
# False 4711 куста
# False 4731 мое
# False 4731 мое
# False 4731 мое
# False 4731 мое
# False 4731 мое
# False 4731 мое
# False 4756 профессора
# False 4756 профессора
# False 4756 профессора
# False 4756 профессора
# False 4784 он
# False 4784 он
# False 4784 он
# False 4784 он
# False 4784 он
# False 4827 вас,
# False 4827 вас,
# False 4827 вас,
# False 4827 вас,
# False 4827 вас,
# False 4827 вас,
# False 4827 вас,
# False 4827 вас,
# False 4827 вас,
# False 4849 он,
# False 4849 он,
# False 4849 он,
# False 4849 он,
# False 4853 я
# False 4853 я
# False 4869 он
# False 4869 он
# False 4869 он
# False 4869 он
# False 4869 он
# False 4869 он
# False 4906 его
# False 4906 его
# False 4906 его
# False 4906 его
# False 4906 его
# False 4906 его
# False 4906 его
# False 4930 Он
# False 4930 Он
# False 4930 Он
# False 4930 Он
# False 4930 Он
# False 4962 колене
# False 4962 колене
# False 4962 колене
# False 4962 колене
# False 4962 колене
# False 4962 колене
# False 4962 колене
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5025 ему
# False 5044 я
# False 5044 я
# False 5044 я
# False 5044 я
# False 5044 я
# False 16 Елена Сергеевна
# False 16 Елена Сергеевна
# False 16 Елена Сергеевна
# False 16 Елена Сергеевна
# False 16 Елена Сергеевна
# False 16 Елена Сергеевна
# False 16 Елена Сергеевна
# False 16 Елена Сергеевна
# False 38 Старая учительница
# False 38 Старая учительница
# False 38 Старая учительница
# False 38 Старая учительница
# False 38 Старая учительница
# False 91 нею
# False 91 нею
# False 91 нею
# False 91 нею
# False 91 нею
# False 91 нею
# False 91 нею
# False 91 нею
# False 101 невысокий молодой человек
# False 101 невысокий молодой человек
# False 128 Он
# False 128 Он
# False 128 Он
# False 128 Он
# False 142 нее
# False 142 нее
# False 142 нее
# False 167 она
# False 167 она
# False 167 она
# False 167 она
# False 167 она
# False 167 она
# False 233 его
# False 233 его
# False 233 его
# False 233 его
# False 233 его
# False 233 его
# False 233 его
# False 233 его
# False 233 его
# False 233 его
# False 233 его
# False 243 Дементьев
# False 243 Дементьев
# False 243 Дементьев
# False 264 она
# False 264 она
# False 264 она
# False 264 она
# False 280 Ты
# False 280 Ты
# False 280 Ты
# False 280 Ты
# False 300 я
# False 300 я
# False 300 я
# False 300 я
# False 300 я
# False 300 я
# False 312 человек
# False 312 человек
# False 312 человек
# False 312 человек
# False 339 Она
# False 339 Она
# False 339 Она
# False 339 Она
# False 339 Она
# False 339 Она
# False 354 он
# False 354 он
# False 354 он
# False 354 он
# False 372 нею
# False 372 нею
# False 372 нею
# False 372 нею
# False 389 ты
# False 389 ты
# False 389 ты
# False 389 ты
# False 389 ты
# False 403 Дементьев
# False 403 Дементьев
# False 403 Дементьев
# False 444 он
# False 444 он
# False 444 он
# False 444 он
# False 444 он
# False 444 он
# False 444 он
# False 444 он
# False 444 он
# False 460 Я
# False 460 Я
# False 460 Я
# False 460 Я
# False 460 Я
# False 460 Я
# False 462 актер
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 549 вы
# False 557 вы - то
# False 557 вы - то
# False 557 вы - то
# False 579 Я
# False 579 Я
# False 579 Я
# False 579 Я
# False 579 Я
# False 579 Я
# False 610 она
# False 610 она
# False 610 она
# False 610 она
# False 610 она
# False 610 она
# False 610 она
# False 610 она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 738 Она
# False 790 Мне
# False 790 Мне
# False 790 Мне
# False 790 Мне
# False 790 Мне
# False 790 Мне
# False 790 Мне
# False 790 Мне
# False 790 Мне
# False 794 комнату новую
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 870 ее
# False 892 Дементьева
# False 892 Дементьева
# False 892 Дементьева
# False 913 вы
# False 913 вы
# False 913 вы
# False 913 вы
# False 940 Елена Сергеевна
# False 940 Елена Сергеевна
# False 940 Елена Сергеевна
# False 940 Елена Сергеевна
# False 940 Елена Сергеевна
# False 966 он
# False 966 он
# False 966 он
# False 966 он
# False 966 он
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1010 комната
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1071 я
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1139 Соседи
# False 1152 Соседи
# False 1152 Соседи
# False 1152 Соседи
# False 1177 Елена Сергеевна
# False 1177 Елена Сергеевна
# False 1177 Елена Сергеевна
# False 1177 Елена Сергеевна
# False 1177 Елена Сергеевна
# False 1177 Елена Сергеевна
# False 1207 я
# False 1207 я
# False 1207 я
# False 1207 я
# False 1207 я
# False 1207 я
# False 1256 Мои
# False 1256 Мои
# False 1256 Мои
# False 1256 Мои
# False 1256 Мои
# False 1256 Мои
# False 1256 Мои
# False 1256 Мои
# False 1256 Мои
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/indexes/api.py:77: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
# False 1290 себя
# False 1290 себя
# False 1290 себя
# False 1290 себя
# False 1290 себя
# False 1290 себя
# False 1290 себя
# False 1326 они
# False 1326 они
# False 1326 они
# False 1326 они
# False 1326 они
# False 1326 они
# False 1326 они
# False 1355 Они
# False 1355 Они
# False 1355 Они
# False 1355 Они
# False 1355 Они
# False 1355 Они
# False 1355 Они
# False 1388 мой
# False 1388 мой
# False 1388 мой
# False 1388 мой
# False 1388 мой
# False 1388 мой
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1438 мне
# False 1498 их
# False 1498 их
# False 1498 их
# False 1498 их
# False 1498 их
# False 1498 их
# False 1498 их
# False 1498 их
# False 1498 их
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1570 ты
# False 1573 мужчина
# False 1582 ты
# False 1582 ты
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1680 Я
# False 1692 ними
# False 1692 ними
# False 1692 ними
# False 1692 ними
# False 1735 Дементьев
# False 1735 Дементьев
# False 1735 Дементьев
# False 1735 Дементьев
# False 1735 Дементьев
# False 1735 Дементьев
# False 1735 Дементьев
# False 1735 Дементьев
# False 1735 Дементьев
# False 1756 него
# False 1756 него
# False 1756 него
# False 1756 него
# False 1756 него
# False 1780 вы
# False 1780 вы
# False 1780 вы
# False 1780 вы
# False 1780 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1828 вы
# False 1857 вас
# False 1857 вас
# False 1857 вас
# False 1857 вас
# False 1857 вас
# False 1857 вас
# False 1876 я
# False 1876 я
# False 1876 я
# False 1876 я
# False 1876 я
# False 1876 я
# False 1888 Я
# False 1888 Я
# False 1888 Я
# False 1908 вам
# False 1908 вам
# False 1908 вам
# False 1908 вам
# False 1935 Елена Сергеевна
# False 1935 Елена Сергеевна
# False 1935 Елена Сергеевна
# False 1935 Елена Сергеевна
# False 1935 Елена Сергеевна
# False 1935 Елена Сергеевна
# False 1986 мне
# False 1986 мне
# False 1986 мне
# False 1986 мне
# False 1986 мне
# False 1986 мне
# False 1986 мне
# False 1986 мне
# False 1986 мне
# False 2000 моей
# False 2000 моей
# False 2000 моей
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2099 ваших
# False 2148 он
# False 2148 он
# False 2148 он
# False 2148 он
# False 2148 он
# False 2148 он
# False 2148 он
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2208 Мадам Мордатенкова
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2289 ней
# False 2324 невысокий человек
# False 2324 невысокий человек
# False 2324 невысокий человек
# False 2324 невысокий человек
# False 2324 невысокий человек
# False 2324 невысокий человек
# False 2324 невысокий человек
# False 2324 невысокий человек
# False 2357 нижней , влажной и отвисшей его губе
# False 2357 нижней , влажной и отвисшей его губе
# False 2357 нижней , влажной и отвисшей его губе
# False 2357 нижней , влажной и отвисшей его губе
# False 2357 нижней , влажной и отвисшей его губе
# False 2357 нижней , влажной и отвисшей его губе
# False 2357 нижней , влажной и отвисшей его губе
# False 2384 его
# False 2384 его
# False 2384 его
# False 2384 его
# False 2384 его
# False 2399 окурок
# False 2399 окурок
# False 2399 окурок
# False 2412 Ты
# False 2412 Ты
# False 2412 Ты
# False 2424 Сергеева
# False 2424 Сергеева
# False 2424 Сергеева
# False 2424 Сергеева
# False 2424 Сергеева
# False 2451 человек в кепочке
# False 2451 человек в кепочке
# False 2451 человек в кепочке
# False 2451 человек в кепочке
# False 2451 человек в кепочке
# False 2490 шокированная всем его видом Мордатенкова
# False 2490 шокированная всем его видом Мордатенкова
# False 2490 шокированная всем его видом Мордатенкова
# False 2490 шокированная всем его видом Мордатенкова
# False 2490 шокированная всем его видом Мордатенкова
# False 2490 шокированная всем его видом Мордатенкова
# False 2490 шокированная всем его видом Мордатенкова
# False 2490 шокированная всем его видом Мордатенкова
# False 2490 шокированная всем его видом Мордатенкова
# False 2508 его
# False 2508 его
# False 2534 Сергеевой
# False 2534 Сергеевой
# False 2534 Сергеевой
# False 2534 Сергеевой
# False 2534 Сергеевой
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2598 кепочка
# False 2610 Оскорбленное достоинство Мордатенковой
# False 2610 Оскорбленное достоинство Мордатенковой
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2758 мадам
# False 2807 она
# False 2807 она
# False 2807 она
# False 2807 она
# False 2807 она
# False 2807 она
# False 2807 она
# False 2807 она
# False 2807 она
# False 2830 Елены Сергеевны
# False 2830 Елены Сергеевны
# False 2830 Елены Сергеевны
# False 2830 Елены Сергеевны
# False 2830 Елены Сергеевны
# False 2859 Незнакомец
# False 2859 Незнакомец
# False 2859 Незнакомец
# False 2859 Незнакомец
# False 2859 Незнакомец
# False 2859 Незнакомец
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2922 его
# False 2938 учительницей
# False 2938 учительницей
# False 2938 учительницей
# False 2985 Мордатенкова
# False 2985 Мордатенкова
# False 2985 Мордатенкова
# False 2985 Мордатенкова
# False 2985 Мордатенкова
# False 2985 Мордатенкова
# False 2985 Мордатенкова
# False 3022 себе
# False 3022 себе
# False 3022 себе
# False 3022 себе
# False 3022 себе
# False 3022 себе
# False 3022 себе
# False 3022 себе
# False 3049 развязного пришельца
# False 3049 развязного пришельца
# False 3049 развязного пришельца
# False 3049 развязного пришельца
# False 3049 развязного пришельца
# False 3088 вы
# False 3088 вы
# False 3088 вы
# False 3088 вы
# False 3088 вы
# False 3088 вы
# False 3088 вы
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3162 Елены Сергеевны
# False 3181 Я
# False 3181 Я
# False 3181 Я
# False 3181 Я
# False 3193 мою - то
# False 3193 мою - то
# False 3193 мою - то
# False 3193 мою - то
# False 3193 мою - то
# False 3193 мою - то
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3240 Нюркой
# False 3248 женой моей
# False 3248 женой моей
# False 3254 моей
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3308 я
# False 3310 те
# False 3324 Я
# False 3324 Я
# False 3324 Я
# False 3324 Я
# False 3326 те
# False 3337 я
# False 3337 я
# False 3337 я
# False 3371 Сама
# False 3371 Сама
# False 3371 Сама
# False 3371 Сама
# False 3371 Сама
# False 3371 Сама
# False 3371 Сама
# False 3371 Сама
# False 3371 Сама
# False 3386 мине
# False 3386 мине
# False 3386 мине
# False 3386 мине
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3508 мне
# False 3512 метры
# False 3530 они
# False 3530 они
# False 3530 они
# False 3530 они
# False 3543 Метры
# False 3543 Метры
# False 3543 Метры
# False 3568 я
# False 3568 я
# False 3568 я
# False 3568 я
# False 3568 я
# False 3568 я
# False 3568 я
# False 3604 Елены Сергеевны
# False 3604 Елены Сергеевны
# False 3604 Елены Сергеевны
# False 3604 Елены Сергеевны
# False 3604 Елены Сергеевны
# False 3604 Елены Сергеевны
# False 3604 Елены Сергеевны
# False 3634 мне
# False 3634 мне
# False 3634 мне
# False 3634 мне
# False 3634 мне
# False 3634 мне
# False 3638 метры
# False 3652 они
# False 3652 они
# False 3652 они
# False 3662 мне
# False 3662 мне
# False 3698 Сергеева
# False 3698 Сергеева
# False 3698 Сергеева
# False 3698 Сергеева
# False 3698 Сергеева
# False 3698 Сергеева
# False 3698 Сергеева
# False 3698 Сергеева
# False 3698 Сергеева
# False 3698 Сергеева
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3751 старшой - то мой
# False 3762 мой
# False 3762 мой
# False 3762 мой
# False 3767 Альбертик - то
# False 3767 Альбертик - то
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3818 он
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 3952 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4071 Шульженко
# False 4096 Альбертиком - то
# False 4096 Альбертиком - то
# False 4096 Альбертиком - то
# False 4096 Альбертиком - то
# False 4096 Альбертиком - то
# False 4096 Альбертиком - то
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4206 я
# False 4208 те
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4315 голос в кепочке
# False 4360 Витька
# False 4360 Витька
# False 4360 Витька
# False 4360 Витька
# False 4360 Витька
# False 4360 Витька
# False 4360 Витька
# False 4360 Витька
# False 4360 Витька
# False 4360 Витька
# False 4368 Младший мой
# False 4368 Младший мой
# False 4376 мой
# False 4381 Ему
# False 4381 Ему
# False 4405 малый
# False 4405 малый
# False 4405 малый
# False 4405 малый
# False 4405 малый
# False 4405 малый
# False 4412 я
# False 4412 я
# False 4414 те
# False 4425 Умница
# False 4425 Умница
# False 4425 Умница
# False 4433 Игрун
# False 4433 Игрун
# False 4440 Ему
# False 4440 Ему
# False 4477 Он
# False 4477 Он
# False 4477 Он
# False 4477 Он
# False 4477 Он
# False 4477 Он
# False 4477 Он
# False 4477 Он
# False 4477 Он
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4583 Ему
# False 4602 Ему
# False 4602 Ему
# False 4602 Ему
# False 4602 Ему
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4675 я
# False 4691 ему
# False 4691 ему
# False 4691 ему
# False 4691 ему
# False 4750 меня
# False 4750 меня
# False 4750 меня
# False 4750 меня
# False 4750 меня
# False 4750 меня
# False 4750 меня
# False 4750 меня
# False 4750 меня
# False 154 черный кот Степан
# False 154 черный кот Степан
# False 154 черный кот Степан
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 228 Он
# False 237 растопыренную пятерню
# False 237 растопыренную пятерню
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 300 обслюненной лапой
# False 320 себя
# False 320 себя
# False 320 себя
# False 328 ухом
# False 328 ухом
# False 344 Степан
# False 344 Степан
# False 344 Степан
# False 392 Он
# False 392 Он
# False 392 Он
# False 392 Он
# False 392 Он
# False 392 Он
# False 392 Он
# False 392 Он
# False 416 лапой
# False 416 лапой
# False 416 лапой
# False 416 лапой
# False 416 лапой
# False 438 ухо
# False 438 ухо
# False 438 ухо
# False 438 ухо
# False 449 Степана
# False 449 Степана
# False 449 Степана
# False 477 Маленький рыжий пес
# False 477 Маленький рыжий пес
# False 477 Маленький рыжий пес
# False 477 Маленький рыжий пес
# False 477 Маленький рыжий пес
# False 510 Одно ухо у него
# False 510 Одно ухо у него
# False 510 Одно ухо у него
# False 510 Одно ухо у него
# False 510 Одно ухо у него
# False 510 Одно ухо у него
# False 521 него
# False 521 него
# False 521 него
# False 563 пес
# False 563 пес
# False 563 пес
# False 563 пес
# False 563 пес
# False 563 пес
# False 563 пес
# False 592 Степану
# False 592 Степану
# False 592 Степану
# False 592 Степану
# False 592 Степану
# False 618 этого загадочного зверя
# False 618 этого загадочного зверя
# False 618 этого загадочного зверя
# False 618 этого загадочного зверя
# False 670 Степан
# False 670 Степан
# False 670 Степан
# False 670 Степан
# False 670 Степан
# False 670 Степан
# False 670 Степан
# False 670 Степан
# False 670 Степан
# False 670 Степан
# False 697 Фунтика
# False 697 Фунтика
# False 697 Фунтика
# False 697 Фунтика
# False 708 вывернутому уху
# False 708 вывернутому уху
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 779 Степана
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1089 Фунтика
# False 1106 Степана
# False 1106 Степана
# False 1106 Степана
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1158 Он
# False 1185 заросший чистотелом сад
# False 1185 заросший чистотелом сад
# False 1185 заросший чистотелом сад
# False 1185 заросший чистотелом сад
# False 1185 заросший чистотелом сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1351 сад
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1494 Степан
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1557 Степана
# False 1602 он
# False 1602 он
# False 1602 он
# False 1602 он
# False 1602 он
# False 1602 он
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1690 Степан
# False 1731 ему
# False 1731 ему
# False 1731 ему
# False 1731 ему
# False 1731 ему
# False 1731 ему
# False 1731 ему
# False 1731 ему
# False 1767 кривоногой собаки
# False 1767 кривоногой собаки
# False 1767 кривоногой собаки
# False 1767 кривоногой собаки
# False 1767 кривоногой собаки
# False 1808 Степана
# False 1808 Степана
# False 1808 Степана
# False 1808 Степана
# False 1808 Степана
# False 1808 Степана
# False 1808 Степана
# False 1808 Степана
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1878 Степан
# False 1894 крыше
# False 1894 крыше
# False 1894 крыше
# False 1894 крыше
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 1971 деревянная миска с мутной водой
# False 2009 нее
# False 2009 нее
# False 2009 нее
# False 2009 нее
# False 2009 нее
# False 2009 нее
# False 2009 нее
# False 2051 Фунтик
# False 2051 Фунтик
# False 2051 Фунтик
# False 2051 Фунтик
# False 2051 Фунтик
# False 2051 Фунтик
# False 2051 Фунтик
# False 2051 Фунтик
# False 2068 миске
# False 2068 миске
# False 2068 миске
# False 2102 большую размокшую корку
# False 2102 большую размокшую корку
# False 2102 большую размокшую корку
# False 2102 большую размокшую корку
# False 2102 большую размокшую корку
# False 2102 большую размокшую корку
# False 2133 Сварливый голенастый петух
# False 2133 Сварливый голенастый петух
# False 2133 Сварливый голенастый петух
# False 2133 Сварливый голенастый петух
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2209 Фунтика
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2282 Петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2382 петух
# False 2409 его
# False 2409 его
# False 2409 его
# False 2409 его
# False 2409 его
# False 2440 него
# False 2440 него
# False 2440 него
# False 2440 него
# False 2440 него
# False 2440 него
# False 2477 петухе
# False 2477 петухе
# False 2477 петухе
# False 2477 петухе
# False 2477 петухе
# False 2477 петухе
# False 2477 петухе
# False 2477 петухе
# False 2477 петухе
# False 2505 Степан
# False 2505 Степан
# False 2505 Степан
# False 2505 Степан
# False 2505 Степан
# False 2536 петух
# False 2536 петух
# False 2536 петух
# False 2536 петух
# False 2536 петух
# False 2536 петух
# False 2536 петух
# False 2536 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2613 петух
# False 2632 Фунтика
# False 2632 Фунтика
# False 2632 Фунтика
# False 2652 его
# False 2652 его
# False 2652 его
# False 2702 Фунтик
# False 2702 Фунтик
# False 2702 Фунтик
# False 2702 Фунтик
# False 2702 Фунтик
# False 2702 Фунтик
# False 2702 Фунтик
# False 2702 Фунтик
# False 2702 Фунтик
# False 2702 Фунтик
# False 2718 хлеб
# False 2718 хлеб
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2780 дом
# False 2791 Петух
# False 2791 Петух
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2853 размокшую корку
# False 2895 ее
# False 2895 ее
# False 2895 ее
# False 2895 ее
# False 2895 ее
# False 2895 ее
# False 2928 корки
# False 2928 корки
# False 2928 корки
# False 2928 корки
# False 2928 корки
# False 2928 корки
# False 2928 корки
# False 2928 корки
# False 2954 Фунтик
# False 2954 Фунтик
# False 2954 Фунтик
# False 2954 Фунтик
# ...
# False 7654 бедного ребенка
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7835 Лапоткина
# False 7858 Соннечка
# False 7858 Соннечка
# False 7858 Соннечка
# False 7858 Соннечка
# False 7858 Соннечка
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7930 Я
# False 7932 тебя
# False 7967 нняньке
# False 7967 нняньке
# False 7967 нняньке
# False 7967 нняньке
# False 7967 нняньке
# False 7967 нняньке
# False 7987 бедная Сонечка
# False 7987 бедная Сонечка
# False 7987 бедная Сонечка
# False 7987 бедная Сонечка
# False 7987 бедная Сонечка
# False 7987 бедная Сонечка
# False 8068 мне
# False 8068 мне
# False 9880 свои
# False 9880 свои
# False 9880 свои
# False 9880 свои
# False 9880 свои
# False 9880 свои
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 9955 Наталья Николаевна
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 10049 ее
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 0 Отец
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 82 Вологду
# False 93 бабушка
# False 93 бабушка
# False 93 бабушка
# False 103 дед
# False 103 дед
# False 155 нами
# False 155 нами
# False 155 нами
# False 155 нами
# False 155 нами
# False 155 нами
# False 155 нами
# False 155 нами
# False 155 нами
# False 155 нами
# False 155 нами
# False 163 деда
# False 163 деда
# False 163 деда
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 284 нам
# False 321 дед
# False 321 дед
# False 321 дед
# False 321 дед
# False 321 дед
# False 321 дед
# False 327 отец
# False 327 отец
# False 388 дедом
# False 388 дедом
# False 388 дедом
# False 388 дедом
# False 388 дедом
# False 388 дедом
# False 388 дедом
# False 388 дедом
# False 388 дедом
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 637 нашу
# False 687 сами помещики
# False 687 сами помещики
# False 687 сами помещики
# False 687 сами помещики
# False 687 сами помещики
# False 687 сами помещики
# False 687 сами помещики
# False 687 сами помещики
# False 687 сами помещики
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 777 сами
# False 802 своего имения
# False 802 своего имения
# False 802 своего имения
# False 802 своего имения
# False 802 своего имения
# False 802 своего имения
# False 819 котором
# False 819 котором
# False 819 котором
# False 819 котором
# False 827 дед
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 959 Вологде
# False 967 мы
# False 1000 купца Крылова
# False 1000 купца Крылова
# False 1000 купца Крылова
# False 1000 купца Крылова
# False 1000 купца Крылова
# False 1000 купца Крылова
# False 1000 купца Крылова
# False 1015 которого
# False 1015 которого
# False 1015 которого
# False 1057 я
# False 1057 я
# False 1057 я
# False 1057 я
# False 1057 я
# False 1057 я
# False 1057 я
# False 1084 он
# False 1084 он
# False 1084 он
# False 1084 он
# False 1084 он
# False 1084 он
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1152 я
# False 1163 него
# False 1163 него
# False 1163 него
# False 1200 дедом
# False 1200 дедом
# False 1200 дедом
# False 1200 дедом
# False 1200 дедом
# False 1200 дедом
# False 1200 дедом
# False 1200 дедом
# False 1200 дедом
# False 1208 имение " Светелки "
# False 1208 имение " Светелки "
# False 1241 Наталии Александровне Назимовой
# False 1241 Наталии Александровне Назимовой
# False 1241 Наталии Александровне Назимовой
# False 1241 Наталии Александровне Назимовой
# False 1241 Наталии Александровне Назимовой
# False 1241 Наталии Александровне Назимовой
# False 1275 Она
# False 1275 Она
# False 1275 Она
# False 1275 Она
# False 1304 Вологде
# False 1304 Вологде
# False 1304 Вологде
# False 1304 Вологде
# False 1304 Вологде
# False 1304 Вологде
# False 1304 Вологде
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1368  Светелки
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1488 лесной речки Тошни
# False 1511 которой
# False 1511 которой
# False 1511 которой
# False 1511 которой
# False 1511 которой
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1614 Назимова
# False 1624 дочь генерала
# False 1624 дочь генерала
# False 1691 Разнатовких
# False 1691 Разнатовких
# False 1691 Разнатовких
# False 1691 Разнатовких
# False 1691 Разнатовких
# False 1691 Разнатовких
# False 1691 Разнатовких
# False 1691 Разнатовких
# False 1691 Разнатовких
# False 1704 родовитых дворян
# False 1704 родовитых дворян
# False 1722 отец которых
# False 1722 отец которых
# False 1722 отец которых
# False 1727 которых
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1806 Петербурге
# False 1818 Он
# False 1818 Он
# False 1841 моего
# False 1841 моего
# False 1841 моего
# False 1841 моего
# False 1841 моего
# False 1864 семья
# False 1864 семья
# False 1864 семья
# False 1864 семья
# False 1864 семья
# False 1885 Вологду
# False 1885 Вологду
# False 1885 Вологду
# False 1900 них
# False 1900 них
# False 1900 них
# False 1900 них
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 1957 Назимовой
# False 2010 доктором Коробовым
# False 2010 доктором Коробовым
# False 2010 доктором Коробовым
# False 2010 доктором Коробовым
# False 2010 доктором Коробовым
# False 2010 доктором Коробовым
# False 2010 доктором Коробовым
# False 2039 Вологде
# False 2039 Вологде
# False 2039 Вологде
# False 2039 Вологде
# False 2039 Вологде
# False 2093 она
# False 2093 она
# False 2093 она
# False 2093 она
# False 2093 она
# False 2093 она
# False 2093 она
# False 2093 она
# False 2093 она
# False 2093 она
# False 2101 Коробов
# False 2101 Коробов
# False 2101 Коробов
# False 2111 Вологде
# False 2111 Вологде
# False 2149 моя
# False 2149 моя
# False 2149 моя
# False 2149 моя
# False 2149 моя
# False 2149 моя
# False 2149 моя
# False 2149 моя
# False 2182 мне
# False 2182 мне
# False 2182 мне
# False 2182 мне
# False 2182 мне
# False 2182 мне
# False 2182 мне
# False 2182 мне
# False 2207 моя
# False 2207 моя
# False 2207 моя
# False 2207 моя
# False 2207 моя
# False 2207 моя

# %%
#print(tokens_with_coref.iloc[1483:1500, 0:6])

#print(cor_list[0:3])
print(len(coreference), len(tokens))
tokens_with_coref.count()
# Out:
# 16557 156636
# doc_id        156636
# shift_o       156636
# length_o      156636
# token         156636
# lemma         156636
# gram          156205
# variant         8373
# group_id        8373
# chain_id        8373
# link            8373
# shift           8373
# length          8373
# content         8373
# tk_shifts       8373
# attributes      8367
# head            2211
# hd_shifts       2212
# anaph           1371
# dtype: int64

# %%
tokens_with_coref['anaph'] = tokens_with_coref['anaph'].fillna(0)
tokens_with_coref = tokens_with_coref.fillna('-')

sum(tokens_with_coref['anaph'])
# Out:
# 1371.0

# %%
from string import punctuation

anaphora = pd.DataFrame({#'chain_id':[],
                        "target":[],"t_gend":[],
                         "t_count":[],"cand":[],"c_gend":[],
                         "c_count":[],'c_pow':[],'dist':[],'answ':[]})
for i, row in tokens_with_coref.iterrows():
    counter = 0
    #print(row.values)
    #print(row['anaph'], row['link'])
    if row['anaph'] == 1 and row['link'] != 0:
        #chain_id = row['chain_id']
        shift = row['shift']
        target_link = row['link']
        target = row['lemma']
        if len(row['gram']) > 4:
            target_gend = row['gram'][4]
            target_count = row['gram'][3]
        else:
            target_gend = '-'
            target_count = '-'
        
        number = 0
        found_answ = False
        while number <= 30:
            counter += 1
            
            if tokens_with_coref.iloc[int(i)-counter-1]['lemma'] not in punctuation:
                i = int(i)
                candidate = tokens_with_coref.iloc[i-counter-1]['lemma']
                
                if len(tokens_with_coref.iloc[i-counter-1]['gram']) > 4:
                    cand_gend = tokens_with_coref.iloc[i-counter-1]['gram'][4]
                    cand_count = tokens_with_coref.iloc[i-counter-1]['gram'][3]
                else:
                    cand_gend = '-'
                    cand_count = '-'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-195-5e93ac9d65e5> in <module>()
#      47                  #               candidate, cand_gend, cand_count, cand_pow, dist, answ])
#      48                 anaphora.loc[len(anaphora)+1] = [target, target_gend, target_count,
# ---> 49                                 candidate, cand_gend, cand_count, cand_pow, dist, answ]
#      50
#      51         if not found_answ:
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     177             key = com._apply_if_callable(key, self.obj)
#     178         indexer = self._get_setitem_indexer(key)
# --> 179         self._setitem_with_indexer(indexer, value)
#     180
#     181     def _has_valid_type(self, k, axis):
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     423                                        name=indexer)
#     424
# --> 425                     self.obj._data = self.obj.append(value)._data
#     426                     self.obj._maybe_update_cacher(clear=True)
#     427                     return self.obj
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity)
#    4625             combined_columns = self.columns.tolist() + self.columns.union(
#    4626                 other.index).difference(self.columns).tolist()
# -> 4627             other = other.reindex(combined_columns, copy=False)
#    4628             other = DataFrame(other.values.reshape((1, len(other))),
#    4629                               index=index,
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    2424     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    2425     def reindex(self, index=None, **kwargs):
# -> 2426         return super(Series, self).reindex(index=index, **kwargs)
#    2427
#    2428     @Appender(generic._shared_docs['fillna'] % _shared_doc_kwargs)
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    2402         # perform the reindex on the axes
#    2403         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 2404                                   fill_value, copy).__finalize__(self)
#    2405
#    2406     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    2415             ax = self._get_axis(a)
#    2416             new_index, indexer = ax.reindex(labels, level=level, limit=limit,
# -> 2417                                             tolerance=tolerance, method=method)
#    2418
#    2419             axis = self._get_axis_number(a)
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    2816             target = self._simple_new(None, dtype=self.dtype, **attrs)
#    2817         else:
# -> 2818             target = _ensure_index(target)
#    2819
#    2820         if level is not None:
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in _ensure_index(index_like, copy)
#    3976             index_like = copy(index_like)
#    3977
# -> 3978     return Index(index_like)
#    3979
#    3980
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     261                 from .numeric import UInt64Index
#     262                 return UInt64Index(data, copy=copy, dtype=dtype, name=name)
# --> 263             elif is_float_dtype(data.dtype):
#     264                 from .numeric import Float64Index
#     265                 return Float64Index(data, copy=copy, dtype=dtype, name=name)
#
# /Users/Ksenia/anaconda/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_float_dtype(arr_or_dtype)
#    1483         return False
#    1484     tipo = _get_dtype_type(arr_or_dtype)
# -> 1485     return issubclass(tipo, np.floating)
#    1486
#    1487
#
# KeyboardInterrupt:
